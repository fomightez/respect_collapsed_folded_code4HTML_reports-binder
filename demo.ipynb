# %% [markdown]
# # Demonstrate the conversion with collapsed/folded cells respected to make a report HTML file
#
# To run this demonstration Jupyter `.ipynb` file hopefully you have started a session already by launching from [my respect_collapsed_folded_code4HTML_reports-binder repo](https://github.com/fomightez/respect_collapsed_folded_code4HTML_reports-binder).
#
# The other notebook is, `the_analysis.ipynb,` just meant to show some code cells and others are collapsed. They can be `uncollapsed` or `unfolded` using Jupyter.
#
# The idea being you can see how it works to make a report with such combinations and then plug pointing the script at your own notebook. (Or testing parts of your content in the test notebook, more piecemeal.) The main script is portable actually so you can also move it to your own Jupyter/Python session. It relies on things that should be available in most vanilla Jupyter installations.
#
# The demonstration notebook , `the_analysis.ipynb,` uses an equation that won't print using the 'Print' directly.<br>
# It also uses collapsed/folded cells that won't print respecting that style when using the 'Print' directly.
#
# Here we will take this notebook
#
# ----
#
#
#
# Let's convert the report to HTML

# %%
# %run convert_to_respect_collapsed_folded_code_and_allow_equations.py the_analysis.ipynb
# Out:
# Saved to the_analysis.html

# %% [markdown]
# Then download that HTML, open in your favorite browser, and print from local computer.

# %% [markdown]
# <details>
#   <summary>✚ <b><i>The inside-scoop</i></b> on printing the 'report'(Click to see details)</summary>
#     <p>Printing nicely formatted showing equations & respecting collapsed code cells:</p>
#     The demonstration notebook uses an equation that won't print using the 'Print' directly.<br>
# It also uses collapsed/folded cells that won't print respecting that style when using the 'Print' directly.<br>
# So I used the advice <a href="https://discourse.jupyter.org/t/equations-rendered-in-notebook-print-preview-not-in-jupyter-lab-print-preview/6081/2?u=fomightez">here</a> to use `nbconvert`. And because I didn't want the code showing, I originally used <code>--no-input</code>, i.e. <code>jupyter nbconvert --to html --no-input the_analysis.ipynb</code>. However, I only wanted the collapsed/folded cells not showing, and so I developed the script <code>convert_to_respect_collapsed_folded_code_and_allow_equations.py</code>.<br>
#
# <p>If you are doing this in the session made for the demonstration, the converstion script will already be resent. Otherwise, put that script <code>convert_to_respect_collapsed_folded_code_and_allow_equations.py</code>  in this session, too, and then run this in the terminal:</p>
#
# <pre><code>python convert_to_respect_collapsed_folded_code_and_allow_equations.py the_analysis.ipynb
# </code></pre>
#
# <p>Then download that HTML, open in browser, and print from local computer.<br>
# Unfortunately, `jupyter nbconvert --to html` command alone seems to move the output over to the left some, and as a result, this approach does that as well. However, it is a minor nuisance.
# </details>

# %% [markdown]
# -------
#
# Enjoy!
